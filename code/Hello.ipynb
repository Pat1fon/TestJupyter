# %%
print('Hello world')
# Out:
# Hello world

# %%
import sys
print(sys.executable)
# Out:
# D:\TestJupyter\venv\Scripts\python.exe

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
