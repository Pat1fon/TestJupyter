# %%
# %pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# !git add .

# %%
# !git commit -m "add git_save"
# Out:
# [main 8bb7ed3] add git_save
#  2 files changed, 217 insertions(+)
#  create mode 100644 git_save/commit_and_push.ipynb
#  create mode 100644 git_save/requirements.txt

# %%
# !git -c core.sshCommand="ssh -o StrictHostKeyChecking=no -i D:/id_ed25519" push
# Out:
# Could not create directory '/c/Users/\354\356\351 \352\356\354\357\374\376\362\345\360/.ssh' (No such file or directory).
# Failed to add the host to the list of known hosts (/c/Users/\354\356\351 \352\356\354\357\374\376\362\345\360/.ssh/known_hosts).
# To github.com:Pat1fon/TestJupyter.git
#    5e2a7b9..8bb7ed3  main -> main
